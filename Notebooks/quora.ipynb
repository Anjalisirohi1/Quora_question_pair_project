# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df.shape
# Out:
# (404290, 6)

# %%
df
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %%
df_data = df.copy()
df_data
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %%
df_data.sample(10)
# Out:
#             id    qid1    qid2  \
# 50335    50335   89437   89438
# 122115  122115   27496  197731
# 90300    90300  151552  151553
# 374796  374796  505729  505730
# 284002  284002  233523  404180
# 198861  198861   89014    2718
# 244206  244206  356800  356801
# 277120  277120  396161  396162
# 46930    46930   83860   83861
# 213847  213847  319293  319294
#
#                                                 question1  \
# 50335     What is better to use: MIT OCW or Khan Academy?
# 122115               What business can I start with $500?
# 90300     What are the scopes of mechatronic engineering?
# 374796  What is the weighted average income in the Uni...
# 284002                                 What's your story?
# 198861  What are the best entrepreneurial decision(s) ...
# 244206  What is your oppinion on the western cultural ...
# 277120     What are the best exercises to improve biceps?
# 46930             How can I get rid of lipo from my body?
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
df_data.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
df_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_data['is_duplicate'].value_counts())
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64

# %%
print((df_data['is_duplicate'].value_counts()/df_data['is_duplicate'].count())*100)
# Out:
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64

# %%
df_data['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_duplicate'>

# %%
qid = pd.Series(df_data['qid1'].tolist()+df_data['qid2'].tolist())

# %%
print('Number of unique quetions are',np.unique(qid).shape[0],'out of',qid.shape[0])
# Out:
# Number of unique quetions are 537933 out of 808580

# %%
print("Number of questions which are repeated are", (qid.value_counts() > 1).sum())
# Out:
# Number of questions which are repeated are 111780

# %%
plt.hist(qid.value_counts().values,bins=160)
plt.yscale('log')
plt.show()
